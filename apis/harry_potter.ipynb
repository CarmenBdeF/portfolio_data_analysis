# %% [markdown]
# Prácticas clase APIs con Happy Potter

# %%
import requests
from PIL import Image
from io import BytesIO
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = "https://hp-api.onrender.com/api/characters"

# %%
res = requests.get(url)

# %%
res.status_code
res.reason
print(res.status_code)
print(res.reason)
# Out:
# 200
# OK

# %%
res.content
# Out:
# b'[{"id":"9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8","name":"Harry Potter","alternate_names":["The Boy Who Lived","The Chosen One","Undesirable No. 1","Potty"],"species":"human","gender":"male","house":"Gryffindor","dateOfBirth":"31-07-1980","yearOfBirth":1980,"wizard":true,"ancestry":"half-blood","eyeColour":"green","hairColour":"black","wand":{"wood":"holly","core":"phoenix tail feather","length":11},"patronus":"stag","hogwartsStudent":true,"hogwartsStaff":false,"actor":"Daniel Radcliffe","alternate_actors":[],"alive":true,"image":"https://ik.imagekit.io/hpapi/harry.jpg"},{"id":"4c7e6819-a91a-45b2-a454-f931e4a7cce3","name":"Hermione Granger","alternate_names":["Hermy","Know-it-all","Miss Grant","Herm-own-ninny"],"species":"human","gender":"female","house":"Gryffindor","dateOfBirth":"19-09-1979","yearOfBirth":1979,"wizard":true,"ancestry":"muggleborn","eyeColour":"brown","hairColour":"brown","wand":{"wood":"vine","core":"dragon heartstring","length":10.75},"patronus":"otter","hogwartsStu
# ...

# %%
res.json()
# Out:
# [{'id': '9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8',
#   'name': 'Harry Potter',
#   'alternate_names': ['The Boy Who Lived',
#    'The Chosen One',
#    'Undesirable No. 1',
#    'Potty'],
#   'species': 'human',
#   'gender': 'male',
#   'house': 'Gryffindor',
#   'dateOfBirth': '31-07-1980',
#   'yearOfBirth': 1980,
#   'wizard': True,
#   'ancestry': 'half-blood',
#   'eyeColour': 'green',
#   'hairColour': 'black',
#   'wand': {'wood': 'holly', 'core': 'phoenix tail feather', 'length': 11},
#   'patronus': 'stag',
#   'hogwartsStudent': True,
#   'hogwartsStaff': False,
#   'actor': 'Daniel Radcliffe',
#   'alternate_actors': [],
#   'alive': True,
#   'image': 'https://ik.imagekit.io/hpapi/harry.jpg'},
#  {'id': '4c7e6819-a91a-45b2-a454-f931e4a7cce3',
#   'name': 'Hermione Granger',
#   'alternate_names': ['Hermy', 'Know-it-all', 'Miss Grant', 'Herm-own-ninny'],
#   'species': 'human',
#   'gender': 'female',
#   'house': 'Gryffindor',
#   'dateOfBirth': '19-09-1979',
# ...

# %%
type(res.json())
# Out:
# list

# %%
personajes = res.json()
personaje = personajes[0]
print(personaje['name'])
print(personaje['patronus'])
print(personaje['wand']['wood'])
# Out:
# Harry Potter
# stag
# holly

# %%
personajes = res.json()
personaje = personajes[1]
print(personaje['name'])
print(personaje['patronus'])
print(personaje['wand']['wood'])
# Out:
# Hermione Granger
# otter
# vine

# %%
personajes = res.json()
personaje = personajes[2]
print(personaje['name'])
print(personaje['patronus'])
print(personaje['wand']['wood'])
# Out:
# Ron Weasley
# Jack Russell terrier
# willow

# %%
for personaje in personajes:
    print(personaje['name'])
# Out:
# Harry Potter
# Hermione Granger
# Ron Weasley
# Draco Malfoy
# Minerva McGonagall
# Cedric Diggory
# Cho Chang
# Severus Snape
# Rubeus Hagrid
# Neville Longbottom
# Luna Lovegood
# Ginny Weasley
# Sirius Black
# Remus Lupin
# Arthur Weasley
# Bellatrix Lestrange
# Lord Voldemort
# Horace Slughorn
# Kingsley Shacklebolt
# Dolores Umbridge
# Lucius Malfoy
# Vincent Crabbe
# Mr Crabbe
# Gregory Goyle
# Mr Goyle
# Mrs Norris
# Argus Filch
# Vernon Dursley
# Petunia Dursley
# Dudley Dursley
# Boa constrictor
# Lily Potter
# James Potter
# Albus Dumbledore
# Fawkes
# Madam Pomfrey
# Mrs Figg
# Marge Dursley
# Ripper
# Yvonne
# Piers Polkiss
# Dennis
# Malcolm
# Gordon
# Miranda Gaushawk
# Bathilda Bagshot
# Adalbert Waffling
# Emeric Switch
# Phyllida Spore
# Arsenius Jigger
# Newt Scamander
# Quentin Trimble
# Tom
# Doris Crockford
# Quirinus Quirrel
# Griphook
# Madam Malkin
# Vindictus Viridian
# Garrick Ollivander
# Hedwig
# Trevor
# Hermes
# Errol
# Pigwidgeon
# Molly Weasley
# ...

# %%
gryffindor = [p for p in personajes if p['house'] == 'Gryffindor']

for p in gryffindor:
    print(p['name'])
# Out:
# Harry Potter
# Hermione Granger
# Ron Weasley
# Minerva McGonagall
# Rubeus Hagrid
# Neville Longbottom
# Ginny Weasley
# Sirius Black
# Remus Lupin
# Arthur Weasley
# Lily Potter
# James Potter
# Albus Dumbledore
# Molly Weasley
# Percy Weasley
# Fred Weasley
# George Weasley
# Lee Jordan
# Bill Weasley
# Charlie Weasley
# Lavender Brown
# Seamus Finnigan
# Parvati Patil
# Nearly Headless Nick
# Angelina Johnson
# Alicia Spinet
# Katie Bell
# Celestina Warbeck
# Colin Creevey
# Peter Pettigrew
# Natalie McDonald
# Eloise Midgen
# Aberforth Dumbledore
# Euan Abercrombie
# Kenneth Towler
# Vicky Frobisher
# Geoffrey Hooper
# Andrew Kirke
# Jack Sloper
# Romilda Vane
# Cormac McLaggen
# Demelza Robins
# Jimmy Peakes
# Ritchie Coote
# Lily Potter
# James Potter
# Rose Weasley

# %%
for p in gryffindor:
    print(f"{p['name']} interpretado por {p['actor']}")
# Out:
# Harry Potter interpretado por Daniel Radcliffe
# Hermione Granger interpretado por Emma Watson
# Ron Weasley interpretado por Rupert Grint
# Minerva McGonagall interpretado por Dame Maggie Smith
# Rubeus Hagrid interpretado por Robbie Coltrane
# Neville Longbottom interpretado por Matthew Lewis
# Ginny Weasley interpretado por Bonnie Wright
# Sirius Black interpretado por Gary Oldman
# Remus Lupin interpretado por David Thewlis
# Arthur Weasley interpretado por Mark Williams
# Lily Potter interpretado por Geraldine Somerville
# James Potter interpretado por Adrian Rawlins
# Albus Dumbledore interpretado por Richard Harris
# Molly Weasley interpretado por Julie Walters
# Percy Weasley interpretado por Chris Rankin
# Fred Weasley interpretado por James Phelps
# George Weasley interpretado por Oliver Phelps
# Lee Jordan interpretado por Luke Youngblood
# Bill Weasley interpretado por Richard Fish
# Charlie Weasley interpretado por Alex Crockford
# ...

# %%
personaje = personajes[0]
image_url = personaje["image"]

# %%
for personaje in personajes[:3]:
    image_url = personaje["image"]
    if image_url:
        res = requests.get(image_url)
        if res.status_code == 200:
            image_data = res.content
            image = Image.open(BytesIO(image_data))

            plt.imshow(image)
            plt.axis("off")
            plt.title(personaje["name"])
            plt.show()

# %%
len(personajes)
# Out:
# 437

# %%
personajes[2]
# Out:
# {'id': 'c3b1f9a5-b87b-48bf-b00d-95b093ea6390',
#  'name': 'Ron Weasley',
#  'alternate_names': ['Dragomir Despard',
#   'Ronald',
#   'Ickle Ronniekins',
#   'Ronnie',
#   'Wheezy',
#   'Won-Won',
#   'Roonil Wazlib'],
#  'species': 'human',
#  'gender': 'male',
#  'house': 'Gryffindor',
#  'dateOfBirth': '01-03-1980',
#  'yearOfBirth': 1980,
#  'wizard': True,
#  'ancestry': 'pure-blood',
#  'eyeColour': 'blue',
#  'hairColour': 'red',
#  'wand': {'wood': 'willow', 'core': 'unicorn tail hair', 'length': 14},
#  'patronus': 'Jack Russell terrier',
#  'hogwartsStudent': True,
#  'hogwartsStaff': False,
#  'actor': 'Rupert Grint',
#  'alternate_actors': [],
#  'alive': True,
#  'image': 'https://ik.imagekit.io/hpapi/ron.jpg'}

# %%
personajes[0].keys()
# Out:
# dict_keys(['id', 'name', 'alternate_names', 'species', 'gender', 'house', 'dateOfBirth', 'yearOfBirth', 'wizard', 'ancestry', 'eyeColour', 'hairColour', 'wand', 'patronus', 'hogwartsStudent', 'hogwartsStaff', 'actor', 'alternate_actors', 'alive', 'image'])

# %%
personajes[0].values()
# Out:
# dict_values(['9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8', 'Harry Potter', ['The Boy Who Lived', 'The Chosen One', 'Undesirable No. 1', 'Potty'], 'human', 'male', 'Gryffindor', '31-07-1980', 1980, True, 'half-blood', 'green', 'black', {'wood': 'holly', 'core': 'phoenix tail feather', 'length': 11}, 'stag', True, False, 'Daniel Radcliffe', [], True, 'https://ik.imagekit.io/hpapi/harry.jpg'])

# %%
pd.DataFrame(personajes)
# Out:
#                                        id                  name  \
# 0    9e3f7ce4-b9a7-4244-b709-dae5c1f1d4a8          Harry Potter
# 1    4c7e6819-a91a-45b2-a454-f931e4a7cce3      Hermione Granger
# 2    c3b1f9a5-b87b-48bf-b00d-95b093ea6390           Ron Weasley
# 3    af95bd8a-dfae-45bb-bc69-533860d34129          Draco Malfoy
# 4    ca3827f0-375a-4891-aaa5-f5e8a5bad225    Minerva McGonagall
# ..                                    ...                   ...
# 432  dcdc063e-cf3e-48fc-b777-65922e899b38  Albus Severus Potter
# 433  e4653b01-76a5-4769-a6a2-1f2efaf89cbb          Rose Weasley
# 434  2b203c7e-7b3d-4f27-8b3c-11473904da73          Hugo Weasley
# 435  7f2f6207-8998-4f98-92c2-8d02898a82eb       Scorpius Malfoy
# 436  57fe29d4-312a-4711-bd9a-c320253d9176      Victoire Weasley
#
#                                        alternate_names species  gender  \
# 0    [The Boy Who Lived, The Chosen One, Undesirabl...   human    male
# ...
